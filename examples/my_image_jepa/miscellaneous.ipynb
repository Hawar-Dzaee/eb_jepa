# %%
from tqdm import tqdm
import time

# %%
iterator = [1,2,3,4,5]
pbar = tqdm(iterable=iterator,desc="Num",disable=False)

for n in pbar:
    print(n)
    time.sleep(0.5)
# Out:
# Num:   0%|          | 0/5 [00:00<?, ?it/s]
# 1
# Num:  20%|██        | 1/5 [00:00<00:02,  1.98it/s]
# 2
# Num:  40%|████      | 2/5 [00:01<00:01,  1.97it/s]
# 3
# Num:  60%|██████    | 3/5 [00:01<00:01,  1.98it/s]
# 4
# Num:  80%|████████  | 4/5 [00:02<00:00,  1.98it/s]
# 5
# Num: 100%|██████████| 5/5 [00:02<00:00,  1.97it/s]
